# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import gc

gc.collect()
# Out:
# 0

# %%
X_train_canvas = np.load('dataset/X_train_canvas.npy')
coords = np.load('dataset/coords.npy')
y_train = np.load('dataset/y_train.npy')
X_test_canvas = np.load('dataset/X_test_canvas.npy')
coords_test = np.load('dataset/coords_test.npy')
y_test = np.load('dataset/y_test.npy')

# %%
X_train_2d = X_train_canvas.reshape(X_train_canvas.shape[0], 128, 128)
X_test_2d = X_test_canvas.reshape(X_test_canvas.shape[0], 128, 128)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(128,128, 1)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),

    Flatten(),

    Dense(248, activation='relu'),
    Dropout(0.5),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(10, activation='softmax')  # Number of neurons for each class
])
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# c:\Users\aless\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(

# %%
from tensorflow.keras.callbacks import TensorBoard

# %%
from tensorflow.keras.callbacks import TensorBoard
import os
import tensorflow as tf

log_dir = "logs"
tensorboard_callback = TensorBoard(log_dir=log_dir)

checkpoint_path = "training_1"
checkpoint_dir = os.path.dirname(checkpoint_path)

# Create a callback that saves the model's weights
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=os.path.join(checkpoint_dir, 'single_epoch_{epoch:02d}.weights.h5'),
                                                 save_weights_only=True,
                                                 verbose=1)


num_epochs = 20
model_run = model.fit(
    X_train_2d,
    y_train,
    epochs=num_epochs,
    batch_size=512,
    validation_data=(X_test_2d, y_test),
    callbacks=[tensorboard_callback, cp_callback],
)
# Out:
# Epoch 1/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4156 - loss: 1.4149
# Epoch 1: saving model to single_epoch_01.weights.h5
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 177s 1s/step - accuracy: 0.4159 - loss: 1.4143 - val_accuracy: 0.6035 - val_loss: 1.0488
# Epoch 2/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5648 - loss: 1.0696
# Epoch 2: saving model to single_epoch_02.weights.h5
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 169s 1s/step - accuracy: 0.5650 - loss: 1.0692 - val_accuracy: 0.7071 - val_loss: 0.7446
# Epoch 3/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6866 - loss: 0.7882
# Epoch 3: saving model to single_epoch_03.weights.h5
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 168s 1s/step - accuracy: 0.6867 - loss: 0.7880 - val_accuracy: 0.7903 - val_loss: 0.5818
# Epoch 4/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7707 - loss: 0.5995
# Epoch 4: saving model to single_epoch_04.weights.h5
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 175s 1s/step - accuracy: 0.7708 - loss: 0.5993 - val_accuracy: 0.8330 - val_loss: 0.4963
# Epoch 5/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8397 - loss: 0.4403
# Epoch 5: saving model to single_epoch_05.weights.h5
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 180s 2s/step - accuracy: 0.8397 - loss: 0.4403 - val_accuracy: 0.8385 - val_loss: 0.4992
# Epoch 6/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8760 - loss: 0.3597
# Epoch 6: saving model to single_epoch_06.weights.h5
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 175s 1s/step - accuracy: 0.8760 - loss: 0.3596 - val_accuracy: 0.8749 - val_loss: 0.4218
# Epoch 7/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9101 - loss: 0.2780
# Epoch 7: saving model to single_epoch_07.weights.h5
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 175s 1s/step - accuracy: 0.9101 - loss: 0.2779 - val_accuracy: 0.8816 - val_loss: 0.3982
# Epoch 8/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9322 - loss: 0.2126
# Epoch 8: saving model to single_epoch_08.weights.h5
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 177s 2s/step - accuracy: 0.9322 - loss: 0.2126 - val_accuracy: 0.8899 - val_loss: 0.3895
# Epoch 9/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9452 - loss: 0.1735
# Epoch 9: saving model to single_epoch_09.weights.h5
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 192s 2s/step - accuracy: 0.9452 - loss: 0.1735 - val_accuracy: 0.8827 - val_loss: 0.4423
# Epoch 10/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9505 - loss: 0.1585
# Epoch 10: saving model to single_epoch_10.weights.h5
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 189s 2s/step - accuracy: 0.9505 - loss: 0.1585 - val_accuracy: 0.8923 - val_loss: 0.4098
# Epoch 11/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9556 - loss: 0.1440
# Epoch 11: saving model to single_epoch_11.weights.h5
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 187s 2s/step - accuracy: 0.9556 - loss: 0.1440 - val_accuracy: 0.9009 - val_loss: 0.3889
# Epoch 12/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9650 - loss: 0.1166
# Epoch 12: saving model to single_epoch_12.weights.h5
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 188s 2s/step - accuracy: 0.9650 - loss: 0.1167 - val_accuracy: 0.9025 - val_loss: 0.3875
# Epoch 13/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9638 - loss: 0.1152
# Epoch 13: saving model to single_epoch_13.weights.h5
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 179s 2s/step - accuracy: 0.9638 - loss: 0.1152 - val_accuracy: 0.9029 - val_loss: 0.3995
# Epoch 14/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9721 - loss: 0.0910
# Epoch 14: saving model to single_epoch_14.weights.h5
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 183s 2s/step - accuracy: 0.9721 - loss: 0.0910 - val_accuracy: 0.9003 - val_loss: 0.4372
# Epoch 15/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9735 - loss: 0.0872
# Epoch 15: saving model to single_epoch_15.weights.h5
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 178s 2s/step - accuracy: 0.9735 - loss: 0.0872 - val_accuracy: 0.9074 - val_loss: 0.4074
# Epoch 16/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9748 - loss: 0.0839
# Epoch 16: saving model to single_epoch_16.weights.h5
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 180s 2s/step - accuracy: 0.9748 - loss: 0.0839 - val_accuracy: 0.9076 - val_loss: 0.4128
# Epoch 17/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9790 - loss: 0.0710
# Epoch 17: saving model to single_epoch_17.weights.h5
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 178s 2s/step - accuracy: 0.9790 - loss: 0.0711 - val_accuracy: 0.9092 - val_loss: 0.4229
# Epoch 18/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9793 - loss: 0.0681
# Epoch 18: saving model to single_epoch_18.weights.h5
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 178s 2s/step - accuracy: 0.9794 - loss: 0.0681 - val_accuracy: 0.9135 - val_loss: 0.4125
# Epoch 19/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9817 - loss: 0.0611
# Epoch 19: saving model to single_epoch_19.weights.h5
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 178s 2s/step - accuracy: 0.9817 - loss: 0.0611 - val_accuracy: 0.8964 - val_loss: 0.5083
# Epoch 20/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9808 - loss: 0.0652
# Epoch 20: saving model to single_epoch_20.weights.h5
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 177s 1s/step - accuracy: 0.9808 - loss: 0.0652 - val_accuracy: 0.9073 - val_loss: 0.4408

# %%
history_model = model_run.history
print("The history has the following data: ", history_model.keys())

# Plotting the training and validation accuracy during the training
sns.lineplot(
    x=model_run.epoch, y=history_model["accuracy"], color="blue", label="Training set"
)
sns.lineplot(
    x=model_run.epoch,
    y=history_model["val_accuracy"],
    color="red",
    label="Valdation set",
)
plt.xlabel("epochs")
plt.ylabel("accuracy")
# Out:
# The history has the following data:  dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])
# c:\Users\aless\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\aless\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\aless\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\aless\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0, 0.5, 'accuracy')

# %%
cp_dir = 'H:\\aless\Documents\Python_Scripts\Matur\mnist\\training_1\single\single_epoch_18.weights.h5'

model.load_weights(cp_dir)

# Evaluating the model on test dataset
model.evaluate(X_test_2d, y_test)
# Out:
# c:\Users\aless\anaconda3\Lib\site-packages\keras\src\saving\saving_lib.py:396: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 26 variables.
#   trackable.load_own_variables(weights_store.get(inner_path))
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.8986 - loss: 0.5033
# [0.41132351756095886, 0.9135000109672546]

# %%
random_sample = np.random.randint(0, X_test_2d.shape[0])

image = X_test_2d[random_sample]
prediction = model.predict(X_test_2d[random_sample].reshape(1, 128, 128, 1))

plt.imshow(image, cmap='gray')
plt.title(f"Predicted: {prediction}")
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
